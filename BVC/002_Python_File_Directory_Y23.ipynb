# %% [markdown]
# # Python Directory and Files Management
#
# In this class, you'll learn about file and directory management in Python, i.e. creating a directory, renaming it, listing all directories, and working with them.
#
# ## Python Directory
#
# If there are a large number of **[files](001_Python_File_Input_Output.ipynb)** to handle in our Python program, we can arrange our code within different directories to make things more manageable.
#
# A directory or folder is a collection of files and subdirectories. Python has the **`os`** **[module]** that provides us with many useful methods to work with directories (and files as well).

# %% [markdown]
# ### Get Current Directory `getcwd()` -
#
# We can get the present working directory using the **`getcwd()`** method of the os module.
#
# This method returns the current working directory in the form of a string. We can also use the **`getcwd()`** method to get it as bytes object.

# %%
import os
print(os.getcwd())
# Out:
# c:\Users\vinay\Downloads\BVC

# %% [markdown]
# The extra backslash implies an escape sequence. The **`print()`** function will render this properly.

# %% [markdown]
# ### Changing Directory `chdir()` -
#
# We can change the current working directory by using the **`chdir()`** method.
#
# The new path that we want to change into must be supplied as a string to this method. We can use both the forward-slash **`/`** or the backward-slash **`\`** to separate the path elements.
#
# It is safer to use an escape sequence when using the backward slash.
#
# **Syntax:**
#
# **`os.chdir("newdir")`**
#
# >**Remember to**:
# 1. First copy the path for current working directory
# 2. Windows user and MacOS users, first create an empty folder with name "**xyz**" on your desktop.

# %%
import os


os.chdir(r"Code_in KrishnaConsiousness") 
  
print("Directory changed") 

print(os.getcwd())
# Out:
# Directory changed
# C:\Users\hp\Downloads\Bootcamp_Y23\Code_in KrishnaConsiousness

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\hp\Downloads\Bootcamp_Y23\Code_in KrishnaConsiousness

# %% [markdown]
# ### List Directories and Files `listdir()` -
#
# The **`listdir()`** method displays all files and sub-directories inside a directory.
#
# This method takes in a path and returns a list of subdirectories and files in that path. If no path is specified, it returns the list of subdirectories and files from the current working directory.

# %%
print(os.getcwd())
print(os.listdir(r'C:\Users\hp\Downloads\Bootcamp_Y23'))

os.listdir()
# Out:
# C:\Users\hp\Downloads\Bootcamp_Y23\Code_in KrishnaConsiousness
# ['Aghgh', 'Code_in KrishnaConsiousness', 'Hare_Krishna_Y23.txt', 'python_study']
# []

# %% [markdown]
# In below example, the specified directory is 'C:\\', which typically refers to the root directory of the C: drive on a Windows system.

# %%
os.listdir('C:\\')
# Out:
# ['$Recycle.Bin',
#  '$WinREAgent',
#  'Config.Msi',
#  'Documents and Settings',
#  'DumpStack.log.tmp',
#  'hiberfil.sys',
#  'Intel',
#  'MinGW',
#  'MSOCache',
#  'NTA UGC NET ENGLISH DETAILED SYLLABUS BY AKSRajveer.pdf',
#  'OneDriveTemp',
#  'pagefile.sys',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'ProgramData',
#  'Recovery',
#  'SALE GST APRIL,MAY 2019.xls',
#  'SALE GST JUNE 2019.xls',
#  'swapfile.sys',
#  'System Volume Information',
#  'takeout-20221020T134800Z-001.tgz',
#  'Users',
#  'Windows']

# %% [markdown]
# ### Making a New Directory `mkdir()` -
#
# You can use the **`mkdir()`** method of the os module to create directories in the current directory. You need to supply an argument to this method, which contains the name of the directory to be created.
#
# This method takes in the path of the new directory. If the full path is not specified, the new directory is created in the current working directory.
#
# **Syntax:**
#
# **`os.mkdir("dir_name")`**

# %%
import os
os.mkdir("Code_in KrishnaConsiousness")

# %%
import os
os.mkdir('python_study')
print("Directory created") 

#os.listdir()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# c:\Users\hp\Downloads\002_Python_File_Directory.ipynb Cell 13 line 2
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/002_Python_File_Directory.ipynb#X20sZmlsZQ%3D%3D?line=0'>1</a> import os
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/002_Python_File_Directory.ipynb#X20sZmlsZQ%3D%3D?line=1'>2</a> os.mkdir('python_study')
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/002_Python_File_Directory.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> print("Directory created")
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/002_Python_File_Directory.ipynb#X20sZmlsZQ%3D%3D?line=4'>5</a> #os.listdir()
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'python_study'

# %% [markdown]
# ### Renaming a Directory or a File `rename()` -
#
# The **`rename()`** method can rename a directory or a file.
#
# **Syntax:**
#
# **`os.rename(current_file_name, new_file_name)`**

# %%
#os.listdir()
os.chdir(r"C:\Users\hp\Downloads\Bootcamp_Y23")
os.rename('python_study','python_learning')
print("Directory renamed") 

os.listdir()
# Out:
# Directory renamed
# ['Aghgh',
#  'Code_in KrishnaConsiousness',
#  'Hare_Krishna_Y23.txt',
#  'python_learning']

# %%
import os
os.rename('Hare_Krishna_Y23.txt','Haribol_Y23.txt')
print("file renamed")
# Out:
# file renamed

# %% [markdown]
# ### Removing a Directory or a File `remove()` and `rmdir()` -
#
# A file can be removed (deleted) using the **`remove()`** method.
# Similarly, the **`rmdir()`** method removes an empty directory. Before removing a directory, all the contents in it should be removed.

# %%
import os

os.rmdir(r"C:\Users\hp\Downloads\Bootcamp_Y23\python_learning")
print("Directory deleted") 

os.listdir()
# Out:
# Directory deleted
# ['Aghgh', 'Code_in KrishnaConsiousness', 'Haribol_Y23.txt']

# %% [markdown]
# >**Note**: The **`rmdir()`** method can only remove empty directories.

# %% [markdown]
# In order to remove a non-empty directory, we can use the **`rmtree()`** method inside the **`shutil`** module.

# %%
import shutil

shutil.rmtree(r"C:\Users\hp\Downloads\Bootcamp_Y23")
os.listdir()
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# c:\Users\hp\Downloads\002_Python_File_Directory.ipynb Cell 22 line 3
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/002_Python_File_Directory.ipynb#X32sZmlsZQ%3D%3D?line=0'>1</a> import shutil
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/002_Python_File_Directory.ipynb#X32sZmlsZQ%3D%3D?line=2'>3</a> shutil.rmtree(r"C:\Users\hp\Downloads\Bootcamp_Y23")
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Downloads/002_Python_File_Directory.ipynb#X32sZmlsZQ%3D%3D?line=3'>4</a> os.listdir()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2032.0_x64__qbz5n2kfra8p0\Lib\shutil.py:759, in rmtree(path, ignore_errors, onerror, dir_fd)
#     757     # can't continue even if onerror hook returns
#     758     return
# --> 759 return _rmtree_unsafe(path, onerror)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2032.0_x64__qbz5n2kfra8p0\Lib\shutil.py:626, in _rmtree_unsafe(path, onerror)
#     624     os.rmdir(path)
#     625 except OSError:
# --> 626     onerror(os.rmdir, path, sys.exc_info())
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2032.0_x64__qbz5n2kfra8p0\Lib\shutil.py:624, in _rmtree_unsafe(path, onerror)
#     622             onerror(os.unlink, fullname, sys.exc_info())
#     623 try:
# --> 624     os.rmdir(path)
#     625 except OSError:
#     626     onerror(os.rmdir, path, sys.exc_info())
#
# PermissionError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\hp\\Downloads\\Bootcamp_Y23'

# %% [markdown]
# Using Python to perform file and directory operations provides several advantages over making changes directly. Here are some reasons:
# 1. Cross-Platform Compatibility: Different operating systems (Windows, Linux, macOS) have different file system structures and path conventions.
# 2. Error Handling:
# 3. Abstraction and Readability: clearly indicates the intention to move a file, while directly manipulating file paths might be less clear.
# 4. Portability:
